# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('MEM_history_model_v1.csv')

# %%
df1.head()
# Out:
#        loss  output_1_loss  output_2_loss  output_1_mse  output_2_accuracy  \
# 0  0.549026       0.046832       0.455363      0.046832           0.853260
# 1  0.496734       0.039992       0.416749      0.039992           0.854486
# 2  0.487005       0.037696       0.411612      0.037696           0.854851
# 3  0.482207       0.036466       0.409275      0.036466           0.855229
# 4  0.479476       0.035626       0.408225      0.035626           0.855239
#
#    val_loss  val_output_1_loss  val_output_2_loss  val_output_1_mse  \
# 0  0.387877           0.050792           0.286292          0.050792
# 1  0.369279           0.043979           0.281320          0.043979
# 2  0.365537           0.042846           0.279845          0.042846
# 3  0.360763           0.040999           0.278765          0.040999
# 4  0.362166           0.041538           0.279089          0.041538
#
#    val_output_2_accuracy
# 0               0.906104
# 1               0.906443
# 2               0.906617
# ...

# %%
plt.plot(df1["output_1_loss"], label='train')
plt.plot(df1["val_output_1_loss"], label='val')
plt.legend()
plt.show()

# %%
plt.plot(df1["output_2_loss"], label='train')
plt.plot(df1["val_output_2_loss"], label='val')
plt.legend()
plt.show()

# %%
plt.plot(df1['loss'], label='train')
plt.plot(df1['val_loss'], label='val')
plt.legend()
plt.show()
