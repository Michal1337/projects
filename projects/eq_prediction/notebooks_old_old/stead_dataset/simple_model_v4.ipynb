# %% [markdown]
# # data_world.csv

# %% [markdown]
# Energia grupowana po regionie i czasie + informacje o regionie + informacje o sasiadach. LSTM, Dense, XGB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import datetime as dt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, f1_score
import tensorflow as tf
import xgboost as xgb
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../../data/merge.csv')
df.head()
# Out:
#   network_code receiver_code receiver_type  receiver_latitude  \
# 0           TA          109C            HH            32.8889
# 1           TA          109C            HH            32.8889
# 2           TA          109C            HH            32.8889
# 3           TA          109C            HH            32.8889
# 4           TA          109C            HH            32.8889
#
#    receiver_longitude  receiver_elevation_m  p_arrival_sample p_status  \
# 0           -117.1051                 150.0               NaN      NaN
# 1           -117.1051                 150.0               NaN      NaN
# 2           -117.1051                 150.0               NaN      NaN
# 3           -117.1051                 150.0               NaN      NaN
# 4           -117.1051                 150.0               NaN      NaN
#
#    p_weight  p_travel_sec  ...  source_magnitude_author  \
# 0       NaN           NaN  ...                      NaN
# 1       NaN           NaN  ...                      NaN
# 2       NaN           NaN  ...                      NaN
# 3       NaN           NaN  ...                      NaN
# 4       NaN           NaN  ...                      NaN
#
#   source_mechanism_strike_dip_rake  source_distance_deg source_distance_km  \
# 0                              NaN                  NaN                NaN
# 1                              NaN                  NaN                NaN
# 2                              NaN                  NaN                NaN
# 3                              NaN                  NaN                NaN
# 4                              NaN                  NaN                NaN
#
#   back_azimuth_deg  snr_db  coda_end_sample     trace_start_time  \
# 0              NaN     NaN              NaN  2015-10-21 05:55:00
# 1              NaN     NaN              NaN  2015-11-06 14:50:00
# 2              NaN     NaN              NaN  2015-11-07 02:20:00
# 3              NaN     NaN              NaN  2015-11-14 05:15:00
# 4              NaN     NaN              NaN  2015-12-25 18:50:00
#
#    trace_category               trace_name
# 0           noise  109C.TA_201510210555_NO
# 1           noise  109C.TA_201511061450_NO
# 2           noise  109C.TA_201511070220_NO
# 3           noise  109C.TA_201511140515_NO
# 4           noise  109C.TA_201512251850_NO
#
# [5 rows x 35 columns]

# %%
df = df[df["trace_category"] == 'earthquake_local']
df.rename(columns={"source_latitude": "latitude", "source_longitude": "longitude", "source_magnitude": "mag", "trace_start_time": "time"}, inplace=True)

# %%
df = df[["time", "latitude", "longitude", "mag"]]

# %%
df["time"] = pd.to_datetime(df["time"], format="mixed")
df
# Out:
#                            time  latitude  longitude   mag
# 235426  2006-07-23 15:59:00.960  33.74960 -117.49380  3.60
# 235427  2006-11-03 15:56:53.610  32.70770 -116.04460  4.30
# 235428  2006-11-03 16:12:24.700  32.72530 -116.03480  3.60
# 235429  2006-11-14 13:32:22.540  32.70630 -116.02410  3.80
# 235430  2006-11-27 10:46:41.060  31.96790 -117.19440  3.60
# ...                         ...       ...        ...   ...
# 1265652 2017-06-21 09:40:43.810  44.77950 -111.03833  0.39
# 1265653 2017-06-21 12:21:05.390  44.76967 -110.99700  1.72
# 1265654 2017-06-21 12:23:40.200  44.77100 -110.99900  1.61
# 1265655 2017-06-21 13:34:40.330  44.77567 -111.03983  1.25
# 1265656 2017-06-21 14:06:11.750  44.75583 -111.02283  0.82
#
# [1030231 rows x 4 columns]

# %%
time_cut = dt.datetime(2004, 1, 1)
df = df[df["time"] > time_cut]
df["energy"] = 10**(1.44*df["mag"]+5.24)
df["label"] = np.where(df["mag"] > 5, 1, 0)

# %%
# keep only year and month in time
df["time"] = df["time"].dt.strftime('%Y-%m')

# %%
geo_split = 10

# %%
df["latitude"] = (df["latitude"] // geo_split).astype(int)
df["latitude"] = df["latitude"] + np.abs(np.min(df["latitude"]))

df["longitude"] = (df["longitude"] // geo_split).astype(int)
df["longitude"] = df["longitude"] + np.abs(np.min(df["longitude"]))
df["pos"] = df["latitude"].astype(str) + "_" + df["longitude"].astype(str)

# %%
def filter_regions(df: pd.DataFrame, threshold: int) -> pd.DataFrame:
    tmp_pos = []
    df_agg = df.groupby(["pos", "time"]).agg({"mag": "count", "label": max}).reset_index()
    for pos in df_agg["pos"].unique():
        tmp = df_agg[df_agg["pos"] == pos]
        tmp = tmp.set_index("time")
        idx = pd.date_range(tmp.index.min(), df_agg["time"].max(), freq="MS").strftime('%Y-%m')
        tmp = tmp.reindex(idx, fill_value=0)
        tmp.index.name = "time"
        tmp["label"] = tmp["label"].shift(-1)
        if tmp["label"].sum() / len(tmp) > threshold:
            tmp_pos.append(pos)
    df = df[df["pos"].isin(tmp_pos)]
    return df

# %%
th = 0.05
df = filter_regions(df, th)

# %%
df
# Out:
#             time  latitude  longitude  mag        energy  label  pos
# 235426   2006-07         8          6  3.6  2.654606e+10      0  8_6
# 235427   2006-11         8          6  4.3  2.703958e+11      0  8_6
# 235428   2006-11         8          6  3.6  2.654606e+10      0  8_6
# 235429   2006-11         8          6  3.8  5.152286e+10      0  8_6
# 235430   2006-11         8          6  3.6  2.654606e+10      0  8_6
# ...          ...       ...        ...  ...           ...    ...  ...
# 1263522  2018-07         8          6  1.2  9.289664e+06      0  8_6
# 1263523  2018-07         8          6  0.9  3.435579e+06      0  8_6
# 1263524  2018-07         8          6  0.9  3.435579e+06      0  8_6
# 1263525  2018-07         8          6  1.1  6.668068e+06      0  8_6
# 1263526  2018-10         8          6  2.8  1.870682e+09      0  8_6
#
# [709556 rows x 7 columns]

# %%
df_agg = df.groupby(["latitude", "longitude", "time"]).agg({"energy": "sum", "label": "max"}).reset_index()
df_agg
# Out:
#       latitude  longitude     time        energy  label
# 0            1         10  2005-03  1.107843e+12      0
# 1            1         10  2010-06  5.058247e+09      0
# 2            1         10  2010-07  1.509850e+13      1
# 3            1         10  2010-08  5.393239e+12      0
# 4            1         10  2010-09  1.742608e+13      1
# ...        ...        ...      ...           ...    ...
# 1573        11          3  2018-08  6.167129e+14      1
# 1574        11          3  2018-09  8.170281e+11      0
# 1575        11          3  2018-10  1.054681e+13      0
# 1576        11          3  2018-11  4.498881e+15      1
# 1577        11          3  2018-12  1.008878e+14      1
#
# [1578 rows x 5 columns]

# %%
df_agg["label"].value_counts()[0] / df_agg["label"].value_counts().sum()
# Out:
# 0.8523447401774398

# %%
def make_ds(df_agg):
    dfs = []
    for i in df_agg["latitude"].unique():
        for j in df_agg["longitude"].unique():
            tmp = df_agg[(df_agg["latitude"] == i) & (df_agg["longitude"] == j)]
            if len(tmp) > 1:
                tmp = tmp.set_index("time")
                idx = pd.date_range(tmp.index.min(), df_agg["time"].max(), freq="MS").strftime('%Y-%m')
                tmp = tmp.reindex(idx, fill_value=0)
                tmp.index.name = "time"
                tmp["label"] = tmp["label"].shift(-1)
                tmp["latitude"] = i
                tmp["longitude"] = j
                tmp["neighbor0"] = 0 
                dfs.append(tmp)
    df_final = pd.concat(dfs)
    return df_final

# %%
df_final = make_ds(df_agg)

# %%
df_final
# Out:
#          latitude  longitude        energy  label  neighbor0
# time
# 2004-07         2        354  5.248075e+11    0.0          0
# 2004-08         2        354  0.000000e+00    0.0          0
# 2004-09         2        354  0.000000e+00    0.0          0
# 2004-10         2        354  0.000000e+00    0.0          0
# 2004-11         2        354  0.000000e+00    0.0          0
# ...           ...        ...           ...    ...        ...
# 2018-08       113         35  4.093718e+14    0.0          0
# 2018-09       113         35  5.342576e+11    0.0          0
# 2018-10       113         35  1.808764e+12    0.0          0
# 2018-11       113         35  1.097306e+12    0.0          0
# 2018-12       113         35  2.664819e+12    NaN          0
#
# [9689 rows x 5 columns]

# %%
for i in df_final["latitude"].unique():
    for j in df_final["longitude"].unique():
        if not df_final[(df_final["latitude"] == i) & (df_final["longitude"] == j)].empty:
            for x in [-5, 0, 5]:
                for y in [-5, 0, 5]:
                    if not df_final[(df_final["latitude"] == i + x) & (df_final["longitude"] == j + y)].empty and not (x == 0 and y == 0):
                        df_final.loc[(df_final["latitude"] == i) & (df_final["longitude"] == j), "neighbor0"] += df_final[(df_final["latitude"] == i + x) & (df_final["longitude"] == j + y)]["energy"]
                        df_final["neighbor0"] = df_final["neighbor0"].fillna(0)

# %%
block_size = 60
dfs_train, dfs_val = [], []
for i in df_final["latitude"].unique():
    for j in df_final["longitude"].unique():
        tmp = df_final[(df_final["latitude"] == i) & (df_final["longitude"] == j)]
        n = int(len(tmp) * 0.2)
        tmp1 = tmp[:-n]
        tmp2 = tmp[-n:]
        if not tmp1.empty and not tmp2.empty:
            scaler = StandardScaler()
            tmp1["neighbor0"] = scaler.fit_transform(tmp1[["neighbor0"]])
            tmp2["neighbor0"] = scaler.transform(tmp2[["neighbor0"]])
            tmp1["energy0"] = scaler.fit_transform(tmp1[["energy"]])
            tmp2["energy0"] = scaler.transform(tmp2[["energy"]])
            for idx in range(1, block_size):
                tmp1["neighbor" + str(idx)] = tmp1["neighbor0"].shift(idx)
                tmp2["neighbor" + str(idx)] = tmp2["neighbor0"].shift(idx)
                tmp1["energy" + str(idx)] = tmp1["energy0"].shift(idx)
                tmp2["energy" + str(idx)] = tmp2["energy0"].shift(idx)  
            dfs_train.append(tmp1)
            dfs_val.append(tmp2)
df_final_train = pd.concat(dfs_train)
df_final_val = pd.concat(dfs_val)

# %%
df_final_train
# Out:
#          latitude  longitude        energy  label  neighbor0   energy0  \
# time
# 2004-07         2        354  5.248075e+11    0.0        0.0 -0.110567
# 2004-08         2        354  0.000000e+00    0.0        0.0 -0.115002
# 2004-09         2        354  0.000000e+00    0.0        0.0 -0.115002
# 2004-10         2        354  0.000000e+00    0.0        0.0 -0.115002
# 2004-11         2        354  0.000000e+00    0.0        0.0 -0.115002
# ...           ...        ...           ...    ...        ...       ...
# 2017-07       113         35  2.130508e+08    0.0        0.0 -0.151674
# 2017-08       113         35  2.987360e+09    0.0        0.0 -0.137989
# 2017-09       113         35  2.037611e+08    0.0        0.0 -0.151720
# 2017-10       113         35  4.164859e+09    0.0        0.0 -0.132180
# 2017-11       113         35  0.000000e+00    0.0        0.0 -0.152725
#
#          neighbor1   energy1  neighbor2   energy2  ...  neighbor55  energy55  \
# time                                               ...
# 2004-07        NaN       NaN        NaN       NaN  ...         NaN       NaN
# 2004-08        0.0 -0.110567        NaN       NaN  ...         NaN       NaN
# 2004-09        0.0 -0.115002        0.0 -0.110567  ...         NaN       NaN
# 2004-10        0.0 -0.115002        0.0 -0.115002  ...         NaN       NaN
# 2004-11        0.0 -0.115002        0.0 -0.115002  ...         NaN       NaN
# ...            ...       ...        ...       ...  ...         ...       ...
# 2017-07        0.0 -0.152197        0.0 -0.152725  ...         NaN       NaN
# 2017-08        0.0 -0.151674        0.0 -0.152197  ...         NaN       NaN
# 2017-09        0.0 -0.137989        0.0 -0.151674  ...         NaN       NaN
# 2017-10        0.0 -0.151720        0.0 -0.137989  ...         NaN       NaN
# 2017-11        0.0 -0.132180        0.0 -0.151720  ...         NaN       NaN
#
#          neighbor56  energy56  neighbor57  energy57  neighbor58  energy58  \
# time
# 2004-07         NaN       NaN         NaN       NaN         NaN       NaN
# 2004-08         NaN       NaN         NaN       NaN         NaN       NaN
# 2004-09         NaN       NaN         NaN       NaN         NaN       NaN
# 2004-10         NaN       NaN         NaN       NaN         NaN       NaN
# 2004-11         NaN       NaN         NaN       NaN         NaN       NaN
# ...             ...       ...         ...       ...         ...       ...
# 2017-07         NaN       NaN         NaN       NaN         NaN       NaN
# 2017-08         NaN       NaN         NaN       NaN         NaN       NaN
# 2017-09         NaN       NaN         NaN       NaN         NaN       NaN
# 2017-10         NaN       NaN         NaN       NaN         NaN       NaN
# 2017-11         NaN       NaN         NaN       NaN         NaN       NaN
#
#          neighbor59  energy59
# time
# 2004-07         NaN       NaN
# 2004-08         NaN       NaN
# 2004-09         NaN       NaN
# 2004-10         NaN       NaN
# 2004-11         NaN       NaN
# ...             ...       ...
# 2017-07         NaN       NaN
# 2017-08         NaN       NaN
# 2017-09         NaN       NaN
# 2017-10         NaN       NaN
# 2017-11         NaN       NaN
#
# [7776 rows x 124 columns]

# %%
df_final_train.dropna(inplace=True)
df_final_val.dropna(inplace=True)

# %%
x_train = df_final_train.drop(["label", "longitude", "latitude", "energy"], axis=1).to_numpy()
y_train = df_final_train["label"].to_numpy()
x_val = df_final_val.drop(["label", "longitude", "latitude", "energy"], axis=1).to_numpy()
y_val = df_final_val["label"].to_numpy()

# %%
x_train = x_train.reshape(-1, block_size, 2)
x_val = x_val.reshape(-1, block_size, 2)
y_train = y_train.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)

# %%
# add anoother column whith 1 - label
y_train = np.concatenate((y_train, 1 - y_train), axis=1)
y_val = np.concatenate((y_val, 1 - y_val), axis=1)

# %%
x_pos_train = df_final_train[["longitude", "latitude"]].to_numpy()
x_pos_val = df_final_val[["longitude", "latitude"]].to_numpy()

# %%
class MyModel(tf.keras.Model):
    def __init__(self, n_embed, vocab_size):
        super(MyModel, self).__init__()
        self.n_embed = n_embed
        self.loc_emb_x = tf.keras.layers.Embedding(vocab_size, n_embed)
        self.loc_emb_y = tf.keras.layers.Embedding(vocab_size, n_embed)
        self.conc = tf.keras.layers.Concatenate()
        self.dense_h = tf.keras.layers.Dense(2 * n_embed)
        self.dense_c = tf.keras.layers.Dense(2 * n_embed)
        self.lstm1 = tf.keras.layers.LSTM(n_embed * 2, return_sequences=True)
        self.lstm2 = tf.keras.layers.LSTM(n_embed * 2)
        self.dense = tf.keras.layers.Dense(n_embed, activation='relu')
        self.out = tf.keras.layers.Dense(2)
        

    def call(self, inputs):
        loc, timestep = inputs
        x = self.loc_emb_x(loc[:, 0])
        y = self.loc_emb_y(loc[:, 1])
        x_loc = self.conc([x, y])
        x_loc = tf.reshape(x_loc, [-1, 2 * self.n_embed])
        h = self.dense_h(x_loc)
        c = self.dense_c(x_loc)
        x = self.lstm1(timestep, initial_state=[c, h])
        x = self.lstm2(x, initial_state=[c, h])
        x = self.dense(x)
        return self.out(x)

# %%
n_embed = 256
vocab_size = 2000
model = MyModel(n_embed, vocab_size)

# %%
model.compile(optimizer='adam',
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                metrics=['accuracy', tf.keras.metrics.F1Score()])

# %%
model.fit([x_pos_train, x_train], y_train, epochs=20, batch_size=32, validation_data=([x_pos_val, x_val], y_val))
# Out:
# Epoch 1/20
# 126/126 [==============================] - 22s 98ms/step - loss: 0.1260 - accuracy: 0.9811 - f1_score: 0.4952
# Epoch 2/20
# 126/126 [==============================] - 7s 56ms/step - loss: 0.0970 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 3/20
# 126/126 [==============================] - 7s 55ms/step - loss: 0.1068 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 4/20
# 126/126 [==============================] - 7s 53ms/step - loss: 0.0941 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 5/20
# 126/126 [==============================] - 6s 50ms/step - loss: 0.0930 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 6/20
# 126/126 [==============================] - 6s 50ms/step - loss: 0.0934 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 7/20
# 126/126 [==============================] - 6s 51ms/step - loss: 0.0933 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 8/20
# 126/126 [==============================] - 7s 52ms/step - loss: 0.0933 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 9/20
# 126/126 [==============================] - 6s 51ms/step - loss: 0.0930 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 10/20
# 126/126 [==============================] - 6s 48ms/step - loss: 0.0936 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 11/20
# 126/126 [==============================] - 6s 50ms/step - loss: 0.0927 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 12/20
# 126/126 [==============================] - 7s 52ms/step - loss: 0.0922 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 13/20
# 126/126 [==============================] - 6s 50ms/step - loss: 0.0930 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 14/20
# 126/126 [==============================] - 7s 52ms/step - loss: 0.0928 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 15/20
# 126/126 [==============================] - 7s 53ms/step - loss: 0.0936 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 16/20
# 126/126 [==============================] - 7s 52ms/step - loss: 0.0925 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 17/20
# 126/126 [==============================] - 8s 61ms/step - loss: 0.0929 - accuracy: 0.9816 - f1_score: 0.4954
# Epoch 18/20
#  57/126 [============>.................] - ETA: 4s - loss: 0.0801 - accuracy: 0.9846 - f1_score: 0.4961
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/majkel/eq_prediction/notebooks/stead_dataset/simple_model_v4.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/majkel/eq_prediction/notebooks/stead_dataset/simple_model_v4.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model.fit([x_pos_train, x_train], y_train, epochs=20, batch_size=32, validation_data=([x_pos_val, x_val], y_val))
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File ~/miniconda3/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
x_train = df_final_train.drop(["label", "energy"], axis=1).to_numpy()
y_train = df_final_train["label"].to_numpy()
x_val = df_final_val.drop(["label", "energy"], axis=1).to_numpy()
y_val = df_final_val["label"].to_numpy()

# %%
model = xgb.XGBClassifier(n_estimators=1000, max_depth=10, learning_rate=0.01, n_jobs=-1)

# %%
model.fit(x_train, y_train, eval_set=[(x_val, y_val)], eval_metric='logloss', early_stopping_rounds=10)
# Out:
# [0]	validation_0-logloss:0.68624
# [1]	validation_0-logloss:0.67951
# [2]	validation_0-logloss:0.67290
# [3]	validation_0-logloss:0.66642
# [4]	validation_0-logloss:0.66005
# [5]	validation_0-logloss:0.65382
# [6]	validation_0-logloss:0.64769
# [7]	validation_0-logloss:0.64167
# [8]	validation_0-logloss:0.63576
# [9]	validation_0-logloss:0.62997
# [10]	validation_0-logloss:0.62427
# [11]	validation_0-logloss:0.61870
# [12]	validation_0-logloss:0.61321
# [13]	validation_0-logloss:0.60781
# [14]	validation_0-logloss:0.60252
# [15]	validation_0-logloss:0.59730
# [16]	validation_0-logloss:0.59220
# [17]	validation_0-logloss:0.58717
# [18]	validation_0-logloss:0.58222
# [19]	validation_0-logloss:0.57740
# [20]	validation_0-logloss:0.57263
# [21]	validation_0-logloss:0.56793
# [22]	validation_0-logloss:0.56329
# [23]	validation_0-logloss:0.55871
# [24]	validation_0-logloss:0.55423
# [25]	validation_0-logloss:0.54980
# [26]	validation_0-logloss:0.54549
# [27]	validation_0-logloss:0.54126
# [28]	validation_0-logloss:0.53705
# [29]	validation_0-logloss:0.53292
# [30]	validation_0-logloss:0.52887
# [31]	validation_0-logloss:0.52490
# [32]	validation_0-logloss:0.52096
# [33]	validation_0-logloss:0.51710
# [34]	validation_0-logloss:0.51333
# [35]	validation_0-logloss:0.50955
# [36]	validation_0-logloss:0.50589
# [37]	validation_0-logloss:0.50225
# [38]	validation_0-logloss:0.49866
# [39]	validation_0-logloss:0.49514
# [40]	validation_0-logloss:0.49168
# [41]	validation_0-logloss:0.48826
# [42]	validation_0-logloss:0.48490
# [43]	validation_0-logloss:0.48163
# [44]	validation_0-logloss:0.47837
# [45]	validation_0-logloss:0.47515
# [46]	validation_0-logloss:0.47199
# [47]	validation_0-logloss:0.46888
# [48]	validation_0-logloss:0.46583
# [49]	validation_0-logloss:0.46282
# [50]	validation_0-logloss:0.45988
# [51]	validation_0-logloss:0.45694
# [52]	validation_0-logloss:0.45405
# [53]	validation_0-logloss:0.45117
# [54]	validation_0-logloss:0.44836
# [55]	validation_0-logloss:0.44559
# [56]	validation_0-logloss:0.44287
# [57]	validation_0-logloss:0.44017
# [58]	validation_0-logloss:0.43753
# [59]	validation_0-logloss:0.43489
# [60]	validation_0-logloss:0.43233
# [61]	validation_0-logloss:0.42976
# [62]	validation_0-logloss:0.42722
# [63]	validation_0-logloss:0.42474
# [64]	validation_0-logloss:0.42229
# [65]	validation_0-logloss:0.41989
# [66]	validation_0-logloss:0.41751
# [67]	validation_0-logloss:0.41517
# [68]	validation_0-logloss:0.41288
# [69]	validation_0-logloss:0.41058
# [70]	validation_0-logloss:0.40834
# [71]	validation_0-logloss:0.40613
# [72]	validation_0-logloss:0.40395
# [73]	validation_0-logloss:0.40182
# [74]	validation_0-logloss:0.39971
# [75]	validation_0-logloss:0.39763
# [76]	validation_0-logloss:0.39557
# [77]	validation_0-logloss:0.39355
# [78]	validation_0-logloss:0.39154
# [79]	validation_0-logloss:0.38954
# [80]	validation_0-logloss:0.38757
# [81]	validation_0-logloss:0.38565
# [82]	validation_0-logloss:0.38373
# [83]	validation_0-logloss:0.38187
# [84]	validation_0-logloss:0.38004
# [85]	validation_0-logloss:0.37821
# [86]	validation_0-logloss:0.37638
# [87]	validation_0-logloss:0.37461
# [88]	validation_0-logloss:0.37286
# [89]	validation_0-logloss:0.37111
# [90]	validation_0-logloss:0.36942
# [91]	validation_0-logloss:0.36770
# [92]	validation_0-logloss:0.36602
# [93]	validation_0-logloss:0.36436
# [94]	validation_0-logloss:0.36272
# [95]	validation_0-logloss:0.36111
# [96]	validation_0-logloss:0.35951
# [97]	validation_0-logloss:0.35794
# [98]	validation_0-logloss:0.35642
# [99]	validation_0-logloss:0.35490
# [100]	validation_0-logloss:0.35338
# [101]	validation_0-logloss:0.35192
# [102]	validation_0-logloss:0.35043
# [103]	validation_0-logloss:0.34897
# [104]	validation_0-logloss:0.34756
# [105]	validation_0-logloss:0.34616
# [106]	validation_0-logloss:0.34475
# [107]	validation_0-logloss:0.34336
# [108]	validation_0-logloss:0.34203
# [109]	validation_0-logloss:0.34070
# [110]	validation_0-logloss:0.33937
# [111]	validation_0-logloss:0.33806
# [112]	validation_0-logloss:0.33676
# [113]	validation_0-logloss:0.33547
# [114]	validation_0-logloss:0.33420
# [115]	validation_0-logloss:0.33296
# [116]	validation_0-logloss:0.33170
# [117]	validation_0-logloss:0.33052
# [118]	validation_0-logloss:0.32934
# [119]	validation_0-logloss:0.32813
# [120]	validation_0-logloss:0.32698
# [121]	validation_0-logloss:0.32583
# [122]	validation_0-logloss:0.32466
# [123]	validation_0-logloss:0.32351
# [124]	validation_0-logloss:0.32237
# [125]	validation_0-logloss:0.32129
# [126]	validation_0-logloss:0.32025
# [127]	validation_0-logloss:0.31918
# [128]	validation_0-logloss:0.31808
# [129]	validation_0-logloss:0.31701
# [130]	validation_0-logloss:0.31599
# [131]	validation_0-logloss:0.31500
# [132]	validation_0-logloss:0.31402
# [133]	validation_0-logloss:0.31302
# [134]	validation_0-logloss:0.31202
# [135]	validation_0-logloss:0.31102
# [136]	validation_0-logloss:0.31010
# [137]	validation_0-logloss:0.30913
# [138]	validation_0-logloss:0.30818
# [139]	validation_0-logloss:0.30725
# [140]	validation_0-logloss:0.30631
# [141]	validation_0-logloss:0.30539
# [142]	validation_0-logloss:0.30449
# [143]	validation_0-logloss:0.30365
# [144]	validation_0-logloss:0.30278
# [145]	validation_0-logloss:0.30192
# [146]	validation_0-logloss:0.30105
# [147]	validation_0-logloss:0.30022
# [148]	validation_0-logloss:0.29938
# [149]	validation_0-logloss:0.29857
# [150]	validation_0-logloss:0.29775
# [151]	validation_0-logloss:0.29692
# [152]	validation_0-logloss:0.29616
# [153]	validation_0-logloss:0.29537
# [154]	validation_0-logloss:0.29458
# [155]	validation_0-logloss:0.29384
# [156]	validation_0-logloss:0.29309
# [157]	validation_0-logloss:0.29232
# [158]	validation_0-logloss:0.29160
# [159]	validation_0-logloss:0.29087
# [160]	validation_0-logloss:0.29018
# [161]	validation_0-logloss:0.28948
# [162]	validation_0-logloss:0.28880
# [163]	validation_0-logloss:0.28813
# [164]	validation_0-logloss:0.28742
# [165]	validation_0-logloss:0.28675
# [166]	validation_0-logloss:0.28608
# [167]	validation_0-logloss:0.28544
# [168]	validation_0-logloss:0.28479
# [169]	validation_0-logloss:0.28418
# [170]	validation_0-logloss:0.28355
# [171]	validation_0-logloss:0.28294
# [172]	validation_0-logloss:0.28233
# [173]	validation_0-logloss:0.28172
# [174]	validation_0-logloss:0.28111
# [175]	validation_0-logloss:0.28054
# [176]	validation_0-logloss:0.27996
# [177]	validation_0-logloss:0.27939
# [178]	validation_0-logloss:0.27882
# [179]	validation_0-logloss:0.27826
# [180]	validation_0-logloss:0.27773
# [181]	validation_0-logloss:0.27718
# [182]	validation_0-logloss:0.27663
# [183]	validation_0-logloss:0.27610
# [184]	validation_0-logloss:0.27556
# [185]	validation_0-logloss:0.27506
# [186]	validation_0-logloss:0.27456
# [187]	validation_0-logloss:0.27405
# [188]	validation_0-logloss:0.27357
# [189]	validation_0-logloss:0.27307
# [190]	validation_0-logloss:0.27257
# [191]	validation_0-logloss:0.27208
# [192]	validation_0-logloss:0.27163
# [193]	validation_0-logloss:0.27114
# [194]	validation_0-logloss:0.27069
# [195]	validation_0-logloss:0.27019
# [196]	validation_0-logloss:0.26970
# [197]	validation_0-logloss:0.26925
# [198]	validation_0-logloss:0.26883
# [199]	validation_0-logloss:0.26840
# [200]	validation_0-logloss:0.26795
# [201]	validation_0-logloss:0.26754
# [202]	validation_0-logloss:0.26711
# [203]	validation_0-logloss:0.26670
# [204]	validation_0-logloss:0.26628
# [205]	validation_0-logloss:0.26588
# [206]	validation_0-logloss:0.26547
# [207]	validation_0-logloss:0.26509
# [208]	validation_0-logloss:0.26470
# [209]	validation_0-logloss:0.26429
# [210]	validation_0-logloss:0.26392
# [211]	validation_0-logloss:0.26354
# [212]	validation_0-logloss:0.26316
# [213]	validation_0-logloss:0.26277
# [214]	validation_0-logloss:0.26241
# [215]	validation_0-logloss:0.26205
# [216]	validation_0-logloss:0.26172
# [217]	validation_0-logloss:0.26135
# [218]	validation_0-logloss:0.26098
# [219]	validation_0-logloss:0.26064
# [220]	validation_0-logloss:0.26029
# [221]	validation_0-logloss:0.25994
# [222]	validation_0-logloss:0.25960
# [223]	validation_0-logloss:0.25926
# [224]	validation_0-logloss:0.25895
# [225]	validation_0-logloss:0.25863
# [226]	validation_0-logloss:0.25830
# [227]	validation_0-logloss:0.25798
# [228]	validation_0-logloss:0.25767
# [229]	validation_0-logloss:0.25737
# [230]	validation_0-logloss:0.25706
# [231]	validation_0-logloss:0.25678
# [232]	validation_0-logloss:0.25650
# [233]	validation_0-logloss:0.25621
# [234]	validation_0-logloss:0.25593
# [235]	validation_0-logloss:0.25564
# [236]	validation_0-logloss:0.25537
# [237]	validation_0-logloss:0.25511
# [238]	validation_0-logloss:0.25485
# [239]	validation_0-logloss:0.25455
# [240]	validation_0-logloss:0.25427
# [241]	validation_0-logloss:0.25399
# [242]	validation_0-logloss:0.25374
# [243]	validation_0-logloss:0.25349
# [244]	validation_0-logloss:0.25322
# [245]	validation_0-logloss:0.25298
# [246]	validation_0-logloss:0.25272
# [247]	validation_0-logloss:0.25247
# [248]	validation_0-logloss:0.25224
# [249]	validation_0-logloss:0.25200
# [250]	validation_0-logloss:0.25178
# [251]	validation_0-logloss:0.25153
# [252]	validation_0-logloss:0.25129
# [253]	validation_0-logloss:0.25107
# [254]	validation_0-logloss:0.25085
# [255]	validation_0-logloss:0.25063
# [256]	validation_0-logloss:0.25040
# [257]	validation_0-logloss:0.25021
# [258]	validation_0-logloss:0.25000
# [259]	validation_0-logloss:0.24979
# [260]	validation_0-logloss:0.24957
# [261]	validation_0-logloss:0.24937
# [262]	validation_0-logloss:0.24919
# [263]	validation_0-logloss:0.24898
# [264]	validation_0-logloss:0.24877
# [265]	validation_0-logloss:0.24856
# [266]	validation_0-logloss:0.24836
# [267]	validation_0-logloss:0.24815
# [268]	validation_0-logloss:0.24796
# [269]	validation_0-logloss:0.24776
# [270]	validation_0-logloss:0.24758
# [271]	validation_0-logloss:0.24740
# [272]	validation_0-logloss:0.24722
# [273]	validation_0-logloss:0.24705
# [274]	validation_0-logloss:0.24686
# [275]	validation_0-logloss:0.24669
# [276]	validation_0-logloss:0.24651
# [277]	validation_0-logloss:0.24633
# [278]	validation_0-logloss:0.24617
# [279]	validation_0-logloss:0.24600
# [280]	validation_0-logloss:0.24584
# [281]	validation_0-logloss:0.24568
# [282]	validation_0-logloss:0.24552
# [283]	validation_0-logloss:0.24537
# [284]	validation_0-logloss:0.24521
# [285]	validation_0-logloss:0.24505
# [286]	validation_0-logloss:0.24488
# [287]	validation_0-logloss:0.24475
# [288]	validation_0-logloss:0.24461
# [289]	validation_0-logloss:0.24447
# [290]	validation_0-logloss:0.24433
# [291]	validation_0-logloss:0.24417
# [292]	validation_0-logloss:0.24403
# [293]	validation_0-logloss:0.24390
# [294]	validation_0-logloss:0.24377
# [295]	validation_0-logloss:0.24363
# [296]	validation_0-logloss:0.24350
# [297]	validation_0-logloss:0.24337
# [298]	validation_0-logloss:0.24325
# [299]	validation_0-logloss:0.24312
# [300]	validation_0-logloss:0.24300
# [301]	validation_0-logloss:0.24288
# [302]	validation_0-logloss:0.24275
# [303]	validation_0-logloss:0.24262
# [304]	validation_0-logloss:0.24250
# [305]	validation_0-logloss:0.24238
# [306]	validation_0-logloss:0.24227
# [307]	validation_0-logloss:0.24216
# [308]	validation_0-logloss:0.24204
# [309]	validation_0-logloss:0.24192
# [310]	validation_0-logloss:0.24181
# [311]	validation_0-logloss:0.24169
# [312]	validation_0-logloss:0.24158
# [313]	validation_0-logloss:0.24146
# [314]	validation_0-logloss:0.24135
# [315]	validation_0-logloss:0.24126
# [316]	validation_0-logloss:0.24116
# [317]	validation_0-logloss:0.24105
# [318]	validation_0-logloss:0.24095
# [319]	validation_0-logloss:0.24086
# [320]	validation_0-logloss:0.24076
# [321]	validation_0-logloss:0.24066
# [322]	validation_0-logloss:0.24055
# [323]	validation_0-logloss:0.24045
# [324]	validation_0-logloss:0.24034
# [325]	validation_0-logloss:0.24025
# [326]	validation_0-logloss:0.24016
# [327]	validation_0-logloss:0.24006
# [328]	validation_0-logloss:0.23998
# [329]	validation_0-logloss:0.23989
# [330]	validation_0-logloss:0.23982
# [331]	validation_0-logloss:0.23973
# [332]	validation_0-logloss:0.23965
# [333]	validation_0-logloss:0.23956
# [334]	validation_0-logloss:0.23948
# [335]	validation_0-logloss:0.23939
# [336]	validation_0-logloss:0.23931
# [337]	validation_0-logloss:0.23924
# [338]	validation_0-logloss:0.23917
# [339]	validation_0-logloss:0.23909
# [340]	validation_0-logloss:0.23901
# [341]	validation_0-logloss:0.23894
# [342]	validation_0-logloss:0.23886
# [343]	validation_0-logloss:0.23877
# [344]	validation_0-logloss:0.23869
# [345]	validation_0-logloss:0.23863
# [346]	validation_0-logloss:0.23856
# [347]	validation_0-logloss:0.23849
# [348]	validation_0-logloss:0.23842
# [349]	validation_0-logloss:0.23835
# [350]	validation_0-logloss:0.23829
# [351]	validation_0-logloss:0.23822
# [352]	validation_0-logloss:0.23815
# [353]	validation_0-logloss:0.23808
# [354]	validation_0-logloss:0.23800
# [355]	validation_0-logloss:0.23794
# [356]	validation_0-logloss:0.23787
# [357]	validation_0-logloss:0.23781
# [358]	validation_0-logloss:0.23774
# [359]	validation_0-logloss:0.23768
# [360]	validation_0-logloss:0.23762
# [361]	validation_0-logloss:0.23755
# [362]	validation_0-logloss:0.23748
# [363]	validation_0-logloss:0.23743
# [364]	validation_0-logloss:0.23738
# [365]	validation_0-logloss:0.23731
# [366]	validation_0-logloss:0.23725
# [367]	validation_0-logloss:0.23721
# [368]	validation_0-logloss:0.23714
# [369]	validation_0-logloss:0.23709
# [370]	validation_0-logloss:0.23706
# [371]	validation_0-logloss:0.23701
# [372]	validation_0-logloss:0.23696
# [373]	validation_0-logloss:0.23690
# [374]	validation_0-logloss:0.23686
# [375]	validation_0-logloss:0.23682
# [376]	validation_0-logloss:0.23676
# [377]	validation_0-logloss:0.23671
# [378]	validation_0-logloss:0.23667
# [379]	validation_0-logloss:0.23662
# [380]	validation_0-logloss:0.23658
# [381]	validation_0-logloss:0.23653
# [382]	validation_0-logloss:0.23650
# [383]	validation_0-logloss:0.23645
# [384]	validation_0-logloss:0.23641
# [385]	validation_0-logloss:0.23637
# [386]	validation_0-logloss:0.23633
# [387]	validation_0-logloss:0.23630
# [388]	validation_0-logloss:0.23626
# [389]	validation_0-logloss:0.23622
# [390]	validation_0-logloss:0.23618
# [391]	validation_0-logloss:0.23613
# [392]	validation_0-logloss:0.23610
# [393]	validation_0-logloss:0.23605
# [394]	validation_0-logloss:0.23601
# [395]	validation_0-logloss:0.23598
# [396]	validation_0-logloss:0.23593
# [397]	validation_0-logloss:0.23590
# [398]	validation_0-logloss:0.23588
# [399]	validation_0-logloss:0.23584
# [400]	validation_0-logloss:0.23580
# [401]	validation_0-logloss:0.23576
# [402]	validation_0-logloss:0.23572
# [403]	validation_0-logloss:0.23568
# [404]	validation_0-logloss:0.23564
# [405]	validation_0-logloss:0.23561
# [406]	validation_0-logloss:0.23558
# [407]	validation_0-logloss:0.23555
# [408]	validation_0-logloss:0.23552
# [409]	validation_0-logloss:0.23550
# [410]	validation_0-logloss:0.23547
# [411]	validation_0-logloss:0.23544
# [412]	validation_0-logloss:0.23542
# [413]	validation_0-logloss:0.23539
# [414]	validation_0-logloss:0.23536
# [415]	validation_0-logloss:0.23533
# [416]	validation_0-logloss:0.23531
# [417]	validation_0-logloss:0.23528
# [418]	validation_0-logloss:0.23524
# [419]	validation_0-logloss:0.23521
# [420]	validation_0-logloss:0.23518
# [421]	validation_0-logloss:0.23514
# [422]	validation_0-logloss:0.23513
# [423]	validation_0-logloss:0.23511
# [424]	validation_0-logloss:0.23508
# [425]	validation_0-logloss:0.23505
# [426]	validation_0-logloss:0.23503
# [427]	validation_0-logloss:0.23501
# [428]	validation_0-logloss:0.23497
# [429]	validation_0-logloss:0.23495
# [430]	validation_0-logloss:0.23493
# [431]	validation_0-logloss:0.23492
# [432]	validation_0-logloss:0.23490
# [433]	validation_0-logloss:0.23487
# [434]	validation_0-logloss:0.23485
# [435]	validation_0-logloss:0.23483
# [436]	validation_0-logloss:0.23481
# [437]	validation_0-logloss:0.23478
# [438]	validation_0-logloss:0.23476
# [439]	validation_0-logloss:0.23474
# [440]	validation_0-logloss:0.23472
# [441]	validation_0-logloss:0.23470
# [442]	validation_0-logloss:0.23468
# [443]	validation_0-logloss:0.23465
# [444]	validation_0-logloss:0.23463
# [445]	validation_0-logloss:0.23460
# [446]	validation_0-logloss:0.23458
# [447]	validation_0-logloss:0.23457
# [448]	validation_0-logloss:0.23455
# [449]	validation_0-logloss:0.23455
# [450]	validation_0-logloss:0.23453
# [451]	validation_0-logloss:0.23450
# [452]	validation_0-logloss:0.23447
# [453]	validation_0-logloss:0.23446
# [454]	validation_0-logloss:0.23446
# [455]	validation_0-logloss:0.23445
# [456]	validation_0-logloss:0.23444
# [457]	validation_0-logloss:0.23442
# [458]	validation_0-logloss:0.23441
# [459]	validation_0-logloss:0.23439
# [460]	validation_0-logloss:0.23438
# [461]	validation_0-logloss:0.23436
# [462]	validation_0-logloss:0.23435
# [463]	validation_0-logloss:0.23433
# [464]	validation_0-logloss:0.23432
# [465]	validation_0-logloss:0.23431
# [466]	validation_0-logloss:0.23431
# [467]	validation_0-logloss:0.23429
# [468]	validation_0-logloss:0.23427
# [469]	validation_0-logloss:0.23426
# [470]	validation_0-logloss:0.23424
# [471]	validation_0-logloss:0.23422
# [472]	validation_0-logloss:0.23420
# [473]	validation_0-logloss:0.23418
# [474]	validation_0-logloss:0.23416
# [475]	validation_0-logloss:0.23414
# [476]	validation_0-logloss:0.23413
# [477]	validation_0-logloss:0.23411
# [478]	validation_0-logloss:0.23410
# [479]	validation_0-logloss:0.23409
# [480]	validation_0-logloss:0.23407
# [481]	validation_0-logloss:0.23404
# [482]	validation_0-logloss:0.23403
# [483]	validation_0-logloss:0.23401
# [484]	validation_0-logloss:0.23399
# [485]	validation_0-logloss:0.23398
# [486]	validation_0-logloss:0.23396
# [487]	validation_0-logloss:0.23395
# [488]	validation_0-logloss:0.23394
# [489]	validation_0-logloss:0.23392
# [490]	validation_0-logloss:0.23391
# [491]	validation_0-logloss:0.23389
# [492]	validation_0-logloss:0.23387
# [493]	validation_0-logloss:0.23386
# [494]	validation_0-logloss:0.23385
# [495]	validation_0-logloss:0.23383
# [496]	validation_0-logloss:0.23382
# [497]	validation_0-logloss:0.23380
# [498]	validation_0-logloss:0.23379
# [499]	validation_0-logloss:0.23377
# [500]	validation_0-logloss:0.23375
# [501]	validation_0-logloss:0.23374
# [502]	validation_0-logloss:0.23373
# [503]	validation_0-logloss:0.23371
# [504]	validation_0-logloss:0.23370
# [505]	validation_0-logloss:0.23368
# [506]	validation_0-logloss:0.23367
# [507]	validation_0-logloss:0.23365
# [508]	validation_0-logloss:0.23363
# [509]	validation_0-logloss:0.23362
# [510]	validation_0-logloss:0.23362
# [511]	validation_0-logloss:0.23362
# [512]	validation_0-logloss:0.23360
# [513]	validation_0-logloss:0.23359
# [514]	validation_0-logloss:0.23358
# [515]	validation_0-logloss:0.23358
# [516]	validation_0-logloss:0.23356
# [517]	validation_0-logloss:0.23355
# [518]	validation_0-logloss:0.23354
# [519]	validation_0-logloss:0.23353
# [520]	validation_0-logloss:0.23352
# [521]	validation_0-logloss:0.23351
# [522]	validation_0-logloss:0.23350
# [523]	validation_0-logloss:0.23349
# [524]	validation_0-logloss:0.23348
# [525]	validation_0-logloss:0.23348
# [526]	validation_0-logloss:0.23347
# [527]	validation_0-logloss:0.23345
# [528]	validation_0-logloss:0.23345
# [529]	validation_0-logloss:0.23345
# [530]	validation_0-logloss:0.23343
# [531]	validation_0-logloss:0.23343
# [532]	validation_0-logloss:0.23342
# [533]	validation_0-logloss:0.23341
# [534]	validation_0-logloss:0.23340
# [535]	validation_0-logloss:0.23339
# [536]	validation_0-logloss:0.23338
# [537]	validation_0-logloss:0.23337
# [538]	validation_0-logloss:0.23336
# [539]	validation_0-logloss:0.23335
# [540]	validation_0-logloss:0.23334
# [541]	validation_0-logloss:0.23333
# [542]	validation_0-logloss:0.23333
# [543]	validation_0-logloss:0.23333
# [544]	validation_0-logloss:0.23331
# [545]	validation_0-logloss:0.23332
# [546]	validation_0-logloss:0.23331
# [547]	validation_0-logloss:0.23330
# [548]	validation_0-logloss:0.23329
# [549]	validation_0-logloss:0.23329
# [550]	validation_0-logloss:0.23328
# [551]	validation_0-logloss:0.23327
# [552]	validation_0-logloss:0.23326
# [553]	validation_0-logloss:0.23325
# [554]	validation_0-logloss:0.23325
# [555]	validation_0-logloss:0.23324
# [556]	validation_0-logloss:0.23324
# [557]	validation_0-logloss:0.23323
# [558]	validation_0-logloss:0.23322
# [559]	validation_0-logloss:0.23321
# [560]	validation_0-logloss:0.23320
# [561]	validation_0-logloss:0.23319
# [562]	validation_0-logloss:0.23319
# [563]	validation_0-logloss:0.23318
# [564]	validation_0-logloss:0.23317
# [565]	validation_0-logloss:0.23318
# [566]	validation_0-logloss:0.23316
# [567]	validation_0-logloss:0.23315
# [568]	validation_0-logloss:0.23315
# [569]	validation_0-logloss:0.23315
# [570]	validation_0-logloss:0.23314
# [571]	validation_0-logloss:0.23314
# [572]	validation_0-logloss:0.23314
# [573]	validation_0-logloss:0.23313
# [574]	validation_0-logloss:0.23312
# [575]	validation_0-logloss:0.23312
# [576]	validation_0-logloss:0.23312
# [577]	validation_0-logloss:0.23311
# [578]	validation_0-logloss:0.23310
# [579]	validation_0-logloss:0.23309
# [580]	validation_0-logloss:0.23308
# [581]	validation_0-logloss:0.23308
# [582]	validation_0-logloss:0.23308
# [583]	validation_0-logloss:0.23308
# [584]	validation_0-logloss:0.23308
# [585]	validation_0-logloss:0.23307
# [586]	validation_0-logloss:0.23307
# [587]	validation_0-logloss:0.23306
# [588]	validation_0-logloss:0.23305
# [589]	validation_0-logloss:0.23304
# [590]	validation_0-logloss:0.23303
# [591]	validation_0-logloss:0.23302
# [592]	validation_0-logloss:0.23301
# [593]	validation_0-logloss:0.23300
# [594]	validation_0-logloss:0.23299
# [595]	validation_0-logloss:0.23299
# [596]	validation_0-logloss:0.23298
# [597]	validation_0-logloss:0.23298
# [598]	validation_0-logloss:0.23297
# [599]	validation_0-logloss:0.23297
# [600]	validation_0-logloss:0.23296
# [601]	validation_0-logloss:0.23296
# [602]	validation_0-logloss:0.23293
# [603]	validation_0-logloss:0.23293
# [604]	validation_0-logloss:0.23291
# [605]	validation_0-logloss:0.23289
# [606]	validation_0-logloss:0.23289
# [607]	validation_0-logloss:0.23287
# [608]	validation_0-logloss:0.23286
# [609]	validation_0-logloss:0.23285
# [610]	validation_0-logloss:0.23285
# [611]	validation_0-logloss:0.23285
# [612]	validation_0-logloss:0.23283
# [613]	validation_0-logloss:0.23283
# [614]	validation_0-logloss:0.23283
# [615]	validation_0-logloss:0.23282
# [616]	validation_0-logloss:0.23282
# [617]	validation_0-logloss:0.23282
# [618]	validation_0-logloss:0.23282
# [619]	validation_0-logloss:0.23281
# [620]	validation_0-logloss:0.23282
# [621]	validation_0-logloss:0.23282
# [622]	validation_0-logloss:0.23282
# [623]	validation_0-logloss:0.23282
# [624]	validation_0-logloss:0.23281
# [625]	validation_0-logloss:0.23281
# [626]	validation_0-logloss:0.23280
# [627]	validation_0-logloss:0.23281
# [628]	validation_0-logloss:0.23280
# [629]	validation_0-logloss:0.23279
# [630]	validation_0-logloss:0.23279
# [631]	validation_0-logloss:0.23278
# [632]	validation_0-logloss:0.23277
# [633]	validation_0-logloss:0.23277
# [634]	validation_0-logloss:0.23276
# [635]	validation_0-logloss:0.23275
# [636]	validation_0-logloss:0.23276
# [637]	validation_0-logloss:0.23276
# [638]	validation_0-logloss:0.23275
# [639]	validation_0-logloss:0.23274
# [640]	validation_0-logloss:0.23274
# [641]	validation_0-logloss:0.23275
# [642]	validation_0-logloss:0.23274
# [643]	validation_0-logloss:0.23274
# [644]	validation_0-logloss:0.23274
# [645]	validation_0-logloss:0.23273
# [646]	validation_0-logloss:0.23273
# [647]	validation_0-logloss:0.23273
# [648]	validation_0-logloss:0.23273
# [649]	validation_0-logloss:0.23272
# [650]	validation_0-logloss:0.23272
# [651]	validation_0-logloss:0.23272
# [652]	validation_0-logloss:0.23272
# [653]	validation_0-logloss:0.23272
# [654]	validation_0-logloss:0.23272
# [655]	validation_0-logloss:0.23271
# [656]	validation_0-logloss:0.23271
# [657]	validation_0-logloss:0.23271
# [658]	validation_0-logloss:0.23271
# [659]	validation_0-logloss:0.23271
# [660]	validation_0-logloss:0.23270
# [661]	validation_0-logloss:0.23270
# [662]	validation_0-logloss:0.23270
# [663]	validation_0-logloss:0.23270
# [664]	validation_0-logloss:0.23270
# [665]	validation_0-logloss:0.23270
# [666]	validation_0-logloss:0.23269
# [667]	validation_0-logloss:0.23269
# [668]	validation_0-logloss:0.23269
# [669]	validation_0-logloss:0.23269
# [670]	validation_0-logloss:0.23269
# [671]	validation_0-logloss:0.23269
# [672]	validation_0-logloss:0.23269
# [673]	validation_0-logloss:0.23269
# [674]	validation_0-logloss:0.23268
# [675]	validation_0-logloss:0.23269
# [676]	validation_0-logloss:0.23268
# [677]	validation_0-logloss:0.23269
# [678]	validation_0-logloss:0.23269
# [679]	validation_0-logloss:0.23268
# [680]	validation_0-logloss:0.23268
# [681]	validation_0-logloss:0.23268
# [682]	validation_0-logloss:0.23267
# [683]	validation_0-logloss:0.23268
# [684]	validation_0-logloss:0.23267
# [685]	validation_0-logloss:0.23268
# [686]	validation_0-logloss:0.23268
# [687]	validation_0-logloss:0.23267
# [688]	validation_0-logloss:0.23267
# [689]	validation_0-logloss:0.23267
# [690]	validation_0-logloss:0.23267
# [691]	validation_0-logloss:0.23267
# [692]	validation_0-logloss:0.23267
# [693]	validation_0-logloss:0.23267
# [694]	validation_0-logloss:0.23267
# [695]	validation_0-logloss:0.23267
# [696]	validation_0-logloss:0.23267
# [697]	validation_0-logloss:0.23267
# [698]	validation_0-logloss:0.23267
# [699]	validation_0-logloss:0.23266
# [700]	validation_0-logloss:0.23266
# [701]	validation_0-logloss:0.23266
# [702]	validation_0-logloss:0.23266
# [703]	validation_0-logloss:0.23266
# [704]	validation_0-logloss:0.23265
# [705]	validation_0-logloss:0.23265
# [706]	validation_0-logloss:0.23265
# [707]	validation_0-logloss:0.23265
# [708]	validation_0-logloss:0.23264
# [709]	validation_0-logloss:0.23264
# [710]	validation_0-logloss:0.23264
# [711]	validation_0-logloss:0.23264
# [712]	validation_0-logloss:0.23264
# [713]	validation_0-logloss:0.23264
# [714]	validation_0-logloss:0.23264
# [715]	validation_0-logloss:0.23263
# [716]	validation_0-logloss:0.23263
# [717]	validation_0-logloss:0.23263
# [718]	validation_0-logloss:0.23263
# [719]	validation_0-logloss:0.23263
# [720]	validation_0-logloss:0.23263
# [721]	validation_0-logloss:0.23262
# [722]	validation_0-logloss:0.23262
# [723]	validation_0-logloss:0.23262
# [724]	validation_0-logloss:0.23262
# [725]	validation_0-logloss:0.23263
# [726]	validation_0-logloss:0.23263
# [727]	validation_0-logloss:0.23262
# [728]	validation_0-logloss:0.23262
# [729]	validation_0-logloss:0.23262
# [730]	validation_0-logloss:0.23262
# [731]	validation_0-logloss:0.23262
# [732]	validation_0-logloss:0.23262
# [733]	validation_0-logloss:0.23262
# [734]	validation_0-logloss:0.23262
# [735]	validation_0-logloss:0.23262
# [736]	validation_0-logloss:0.23262
# [737]	validation_0-logloss:0.23262
# [738]	validation_0-logloss:0.23261
# [739]	validation_0-logloss:0.23261
# [740]	validation_0-logloss:0.23262
# [741]	validation_0-logloss:0.23262
# [742]	validation_0-logloss:0.23263
# [743]	validation_0-logloss:0.23263
# [744]	validation_0-logloss:0.23263
# [745]	validation_0-logloss:0.23263
# [746]	validation_0-logloss:0.23263
# [747]	validation_0-logloss:0.23264
# [748]	validation_0-logloss:0.23264
# [749]	validation_0-logloss:0.23263
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=1000, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(x_val)
accuracy_score(y_val, y_pred), f1_score(y_val, y_pred)
# Out:
# (0.9064726515400636, 0.5715003138731952)
